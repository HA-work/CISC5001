# %%
# %tensorflow_version 2.x
import tensorflow as tf
tf.__version__

#setting up and downloading
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf
import pandas as pd

CSV_COLUMN_NAMES = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Species']
SPECIES = ['Setosa', 'Versicolor', 'Virginica']

train_path = tf.keras.utils.get_file(
    "iris_training.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_training.csv")
test_path = tf.keras.utils.get_file(
    "iris_test.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_test.csv")

train = pd.read_csv(train_path, names=CSV_COLUMN_NAMES, header=0)
test = pd.read_csv(test_path, names=CSV_COLUMN_NAMES, header=0)


#playing around and printing stuff
print(train.head())


train_y = train.pop('Species')
test_y = test.pop('Species')

# The label column has now been removed from the features.
train.head()



#
def input_evaluation_set():
    features = {'SepalLength': np.array([6.4, 5.0]),
                'SepalWidth':  np.array([2.8, 2.3]),
                'PetalLength': np.array([5.6, 3.3]),
                'PetalWidth':  np.array([2.2, 1.0])}
    labels = np.array([2, 1])
    return features, labels


def input_fn(features, labels, training=True, batch_size=256):
    """An input function for training or evaluating"""
    # Convert the inputs to a Dataset.
    dataset = tf.data.Dataset.from_tensor_slices((dict(features), labels))

    # Shuffle and repeat if you are in training mode.
    if training:
        dataset = dataset.shuffle(1000).repeat()
    
    return dataset.batch(batch_size)


# Feature columns describe how to use the input.
my_feature_columns = []
for key in train.keys():
    my_feature_columns.append(tf.feature_column.numeric_column(key=key))


# Build a DNN with 2 hidden layers with 30 and 10 hidden nodes each.
classifier = tf.estimator.DNNClassifier(
    feature_columns=my_feature_columns,
    # Two hidden layers of 30 and 10 nodes respectively.
    hidden_units=[30, 10],
    # The model must choose between 3 classes.
    n_classes=3)


# Train the Model.
classifier.train(
    input_fn=lambda: input_fn(train, train_y, training=True),
    steps=5000)


eval_result = classifier.evaluate(
    input_fn=lambda: input_fn(test, test_y, training=False))

print('\nTest set accuracy: {accuracy:0.3f}\n'.format(**eval_result))



# Generate predictions from the model
expected = ['Setosa', 'Versicolor', 'Virginica']
predict_x = {
    'SepalLength': [5.1, 5.9, 6.9],
    'SepalWidth': [3.3, 3.0, 3.1],
    'PetalLength': [1.7, 4.2, 5.4],
    'PetalWidth': [0.5, 1.5, 2.1],
}

def input_fn(features, batch_size=256):
    """An input function for prediction."""
    # Convert the inputs to a Dataset without labels.
    return tf.data.Dataset.from_tensor_slices(dict(features)).batch(batch_size)

predictions = classifier.predict(
    input_fn=lambda: input_fn(predict_x))



for pred_dict, expec in zip(predictions, expected):
    class_id = pred_dict['class_ids'][0]
    probability = pred_dict['probabilities'][class_id]

    print('Prediction is "{}" ({:.1f}%), expected "{}"'.format(
        SPECIES[class_id], 100 * probability, expec))
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth  Species
# 0          6.4         2.8          5.6         2.2        2
# 1          5.0         2.3          3.3         1.0        1
# 2          4.9         2.5          4.5         1.7        2
# 3          4.9         3.1          1.5         0.1        0
# 4          5.7         3.8          1.7         0.3        0
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpnvx2c5by
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpnvx2c5by', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpnvx2c5by/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 1.3164445, step = 0
# INFO:tensorflow:global_step/sec: 454.793
# INFO:tensorflow:loss = 0.9614382, step = 100 (0.225 sec)
# INFO:tensorflow:global_step/sec: 529.315
# INFO:tensorflow:loss = 0.90124875, step = 200 (0.187 sec)
# INFO:tensorflow:global_step/sec: 584.298
# INFO:tensorflow:loss = 0.865396, step = 300 (0.173 sec)
# INFO:tensorflow:global_step/sec: 552.293
# INFO:tensorflow:loss = 0.827095, step = 400 (0.182 sec)
# INFO:tensorflow:global_step/sec: 582.508
# INFO:tensorflow:loss = 0.80003035, step = 500 (0.168 sec)
# INFO:tensorflow:global_step/sec: 577.314
# INFO:tensorflow:loss = 0.77774704, step = 600 (0.174 sec)
# INFO:tensorflow:global_step/sec: 577.089
# INFO:tensorflow:loss = 0.74775076, step = 700 (0.177 sec)
# INFO:tensorflow:global_step/sec: 510.199
# INFO:tensorflow:loss = 0.7379601, step = 800 (0.192 sec)
# INFO:tensorflow:global_step/sec: 593.436
# INFO:tensorflow:loss = 0.7000625, step = 900 (0.172 sec)
# INFO:tensorflow:global_step/sec: 481.807
# INFO:tensorflow:loss = 0.6895594, step = 1000 (0.204 sec)
# INFO:tensorflow:global_step/sec: 551.242
# INFO:tensorflow:loss = 0.6639843, step = 1100 (0.183 sec)
# INFO:tensorflow:global_step/sec: 544.509
# INFO:tensorflow:loss = 0.6490295, step = 1200 (0.182 sec)
# INFO:tensorflow:global_step/sec: 557.939
# INFO:tensorflow:loss = 0.6283012, step = 1300 (0.180 sec)
# INFO:tensorflow:global_step/sec: 475.277
# INFO:tensorflow:loss = 0.6145644, step = 1400 (0.209 sec)
# INFO:tensorflow:global_step/sec: 558.983
# INFO:tensorflow:loss = 0.61090744, step = 1500 (0.180 sec)
# INFO:tensorflow:global_step/sec: 601.72
# INFO:tensorflow:loss = 0.5902598, step = 1600 (0.168 sec)
# INFO:tensorflow:global_step/sec: 570.747
# INFO:tensorflow:loss = 0.5724079, step = 1700 (0.173 sec)
# INFO:tensorflow:global_step/sec: 533.011
# INFO:tensorflow:loss = 0.562562, step = 1800 (0.190 sec)
# INFO:tensorflow:global_step/sec: 557.545
# INFO:tensorflow:loss = 0.54843974, step = 1900 (0.179 sec)
# INFO:tensorflow:global_step/sec: 589.439
# INFO:tensorflow:loss = 0.5413872, step = 2000 (0.167 sec)
# INFO:tensorflow:global_step/sec: 529.287
# INFO:tensorflow:loss = 0.5338718, step = 2100 (0.190 sec)
# INFO:tensorflow:global_step/sec: 556.047
# INFO:tensorflow:loss = 0.51987076, step = 2200 (0.181 sec)
# INFO:tensorflow:global_step/sec: 541.505
# INFO:tensorflow:loss = 0.50721, step = 2300 (0.185 sec)
# INFO:tensorflow:global_step/sec: 525.156
# INFO:tensorflow:loss = 0.49412993, step = 2400 (0.189 sec)
# INFO:tensorflow:global_step/sec: 489.951
# INFO:tensorflow:loss = 0.5127548, step = 2500 (0.203 sec)
# INFO:tensorflow:global_step/sec: 516.224
# INFO:tensorflow:loss = 0.48698872, step = 2600 (0.196 sec)
# INFO:tensorflow:global_step/sec: 565.953
# INFO:tensorflow:loss = 0.4777198, step = 2700 (0.177 sec)
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 2746 vs previous value: 2746. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# INFO:tensorflow:global_step/sec: 517.213
# INFO:tensorflow:loss = 0.47444838, step = 2800 (0.191 sec)
# INFO:tensorflow:global_step/sec: 558.671
# INFO:tensorflow:loss = 0.46596652, step = 2900 (0.179 sec)
# INFO:tensorflow:global_step/sec: 485.815
# INFO:tensorflow:loss = 0.46523374, step = 3000 (0.206 sec)
# INFO:tensorflow:global_step/sec: 533.942
# INFO:tensorflow:loss = 0.4571119, step = 3100 (0.189 sec)
# INFO:tensorflow:global_step/sec: 564.979
# INFO:tensorflow:loss = 0.43872365, step = 3200 (0.177 sec)
# INFO:tensorflow:global_step/sec: 577.224
# INFO:tensorflow:loss = 0.44319963, step = 3300 (0.171 sec)
# INFO:tensorflow:global_step/sec: 569.152
# INFO:tensorflow:loss = 0.4307676, step = 3400 (0.178 sec)
# INFO:tensorflow:global_step/sec: 575.451
# INFO:tensorflow:loss = 0.41479686, step = 3500 (0.174 sec)
# INFO:tensorflow:global_step/sec: 550.441
# INFO:tensorflow:loss = 0.4236037, step = 3600 (0.180 sec)
# INFO:tensorflow:global_step/sec: 548.135
# INFO:tensorflow:loss = 0.41786727, step = 3700 (0.184 sec)
# INFO:tensorflow:global_step/sec: 540.566
# INFO:tensorflow:loss = 0.4271754, step = 3800 (0.183 sec)
# INFO:tensorflow:global_step/sec: 580.04
# INFO:tensorflow:loss = 0.41999274, step = 3900 (0.172 sec)
# INFO:tensorflow:global_step/sec: 647.261
# INFO:tensorflow:loss = 0.40654975, step = 4000 (0.155 sec)
# INFO:tensorflow:global_step/sec: 605.325
# INFO:tensorflow:loss = 0.40341282, step = 4100 (0.167 sec)
# INFO:tensorflow:global_step/sec: 571.37
# INFO:tensorflow:loss = 0.40683004, step = 4200 (0.175 sec)
# INFO:tensorflow:global_step/sec: 612.5
# INFO:tensorflow:loss = 0.39501178, step = 4300 (0.164 sec)
# INFO:tensorflow:global_step/sec: 613.335
# INFO:tensorflow:loss = 0.3932429, step = 4400 (0.162 sec)
# INFO:tensorflow:global_step/sec: 627.716
# INFO:tensorflow:loss = 0.38763237, step = 4500 (0.158 sec)
# INFO:tensorflow:global_step/sec: 611.565
# INFO:tensorflow:loss = 0.38289207, step = 4600 (0.163 sec)
# INFO:tensorflow:global_step/sec: 647.311
# INFO:tensorflow:loss = 0.38482296, step = 4700 (0.159 sec)
# INFO:tensorflow:global_step/sec: 617.413
# INFO:tensorflow:loss = 0.37940845, step = 4800 (0.158 sec)
# INFO:tensorflow:global_step/sec: 592.603
# INFO:tensorflow:loss = 0.36972827, step = 4900 (0.168 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 5000...
# INFO:tensorflow:Saving checkpoints for 5000 into /tmp/tmpnvx2c5by/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 5000...
# INFO:tensorflow:Loss for final step: 0.36560637.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-11-01T16:42:20Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpnvx2c5by/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.20092s
# INFO:tensorflow:Finished evaluation at 2020-11-01-16:42:20
# INFO:tensorflow:Saving dict for global step 5000: accuracy = 0.93333334, average_loss = 0.43604532, global_step = 5000, loss = 0.43604532
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5000: /tmp/tmpnvx2c5by/model.ckpt-5000
#
# Test set accuracy: 0.933
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpnvx2c5by/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Prediction is "Setosa" (84.6%), expected "Setosa"
# Prediction is "Versicolor" (52.5%), expected "Versicolor"
# Prediction is "Virginica" (63.3%), expected "Virginica"
